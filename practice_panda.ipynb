# %% [markdown]
# # Explore the panda.

# %%
import numpy as np
import pandas as pd

# %%
# check the version of panda.
pd.__version__
# Out:
# '2.2.2'

# %%
# Create a DataFrame.

student = {
    "name" : ['Joy', 'Turjo', 'Junak', 'Sabbir', 'Fahad', 'Mostafiz', 'Nova'],
    "age" :  [24, 34, 45, 56, 67, 78, 88],
    "area" : ['Mirabazar', 'Modinamrket', 'Bateshwer', 'Subid-bazar', 'Uposhohor', 'Londoni-road', 'Housing-state'],
    "cgpa" : [2.31, 3.50, 3.90, 3.85, 3.75, 4.00, 4.00]

}

# %%
stu_df = pd.DataFrame(student)

# %%
stu_df
# Out:
#        name  age           area  cgpa
# 0       Joy   24      Mirabazar  2.31
# 1     Turjo   34    Modinamrket  3.50
# 2     Junak   45      Bateshwer  3.90
# 3    Sabbir   56    Subid-bazar  3.85
# 4     Fahad   67      Uposhohor  3.75
# 5  Mostafiz   78   Londoni-road  4.00
# 6      Nova   88  Housing-state  4.00

# %%
# see the first 4 student.
stu_df.head(4)
# Out:
#      name  age         area  cgpa
# 0     Joy   24    Mirabazar  2.31
# 1   Turjo   34  Modinamrket  3.50
# 2   Junak   45    Bateshwer  3.90
# 3  Sabbir   56  Subid-bazar  3.85

# %%
# see the last 4 students.
stu_df.tail(4)
# Out:
#        name  age           area  cgpa
# 3    Sabbir   56    Subid-bazar  3.85
# 4     Fahad   67      Uposhohor  3.75
# 5  Mostafiz   78   Londoni-road  4.00
# 6      Nova   88  Housing-state  4.00

# %%
# shape.
stu_df.shape
# Out:
# (7, 4)

# %%
# see all info of my dataframe.
stu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    7 non-null      object
#  1   age     7 non-null      int64
#  2   area    7 non-null      object
#  3   cgpa    7 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 356.0+ bytes

# %%
# describe the dataFrame.
stu_df.describe()
# Out:
#             age      cgpa
# count   7.00000  7.000000
# mean   56.00000  3.615714
# std    23.30236  0.601023
# min    24.00000  2.310000
# 25%    39.50000  3.625000
# 50%    56.00000  3.850000
# 75%    72.50000  3.950000
# max    88.00000  4.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['cgpa'].plot(kind='hist', bins=20, title='cgpa')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='age', y='cgpa', s=32, alpha=.8)
# ...

# %%
# print the all value in the current dataframe.
print(stu_df.values)
# Out:
# [['Joy' 24 'Mirabazar' 2.31]
#  ['Turjo' 34 'Modinamrket' 3.5]
#  ['Junak' 45 'Bateshwer' 3.9]
#  ['Sabbir' 56 'Subid-bazar' 3.85]
#  ['Fahad' 67 'Uposhohor' 3.75]
#  ['Mostafiz' 78 'Londoni-road' 4.0]
#  ['Nova' 88 'Housing-state' 4.0]]

# %%
# print the type of dataframe.
print(type(stu_df))
print(type(stu_df.values))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
# we can change the coloum name.

stu_df.columns = ["Name", "Experience", "City", "GPA"]

# %%
stu_df
# Out:
#        Name  Experience           City   GPA
# 0       Joy          24      Mirabazar  2.31
# 1     Turjo          34    Modinamrket  3.50
# 2     Junak          45      Bateshwer  3.90
# 3    Sabbir          56    Subid-bazar  3.85
# 4     Fahad          67      Uposhohor  3.75
# 5  Mostafiz          78   Londoni-road  4.00
# 6      Nova          88  Housing-state  4.00

# %%
stu_df.head()
# Out:
#      Name  Experience         City   GPA
# 0     Joy          24    Mirabazar  2.31
# 1   Turjo          34  Modinamrket  3.50
# 2   Junak          45    Bateshwer  3.90
# 3  Sabbir          56  Subid-bazar  3.85
# 4   Fahad          67    Uposhohor  3.75

# %%
df = pd.read_csv('/content/canada_per_capita_income.csv')

# %%
df.sample
# Out:
#    Unnamed: 0      Name  Experience           City   GPA
# 0           0       Joy          24      Mirabazar  2.31
# 1           1     Turjo          34    Modinamrket  3.50
# 2           2     Junak          45      Bateshwer  3.90
# 3           3    Sabbir          56    Subid-bazar  3.85
# 4           4     Fahad          67      Uposhohor  3.75
# 5           5  Mostafiz          78   Londoni-road  4.00
# 6           6      Nova          88  Housing-state  4.00
